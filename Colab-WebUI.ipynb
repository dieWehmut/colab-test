# %% [markdown]
# <a href="https://colab.research.google.com/github/dieWehmut/colab-test/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Overwriting /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ✨🍰✨ Everything looks OK!
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# bash: /usr/local/lib/libtinfo.so.6: no version information available (required by bash)
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# 1. 卸载当前冲突的版本
# !/usr/local/envs/GPTSoVITS/bin/pip uninstall torch torchaudio torchcodec -y

# 2. 安装黄金搭档 (Torch 2.1.2 + Torchaudio 2.1.2)
# 指定 CUDA 118 源，确保 GPU 加速正常
# !/usr/local/envs/GPTSoVITS/bin/pip install torch==2.1.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu118

# 3. 补充组件
# !/usr/local/envs/GPTSoVITS/bin/pip install soundfile numpy
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Found existing installation: torch 2.9.1+cu126
# Uninstalling torch-2.9.1+cu126:
#   Successfully uninstalled torch-2.9.1+cu126
# Found existing installation: torchaudio 2.3.0
# Uninstalling torchaudio-2.3.0:
#   Successfully uninstalled torchaudio-2.3.0
# WARNING: Skipping torchcodec as it is not installed.
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 12.1 MB/s  0:00:58
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 125.7 MB/s  0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 69.3 MB/s  0:00:01
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.5.1
#     Uninstalling triton-3.5.1:
#       Successfully uninstalled triton-3.5.1
# ...

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://ede776d8096fc59d47.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/prepare_datasets/2-get-hubert-wav32k.py
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/prepare_datasets/2-get-hubert-wav32k.py
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# ...

# %%
import os

# 1. 切换目录
os.chdir('/content/GPT-SoVITS')

# 2. 设置分享
os.environ['is_share'] = 'True'

# 3. 启动！
print("🚀 正在启动推理界面...")
# !/usr/local/envs/GPTSoVITS/bin/python GPT_SoVITS/inference_webui.py
# Out:
# 🚀 正在启动推理界面...
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/jieba/_compat.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# SoVITS_weights_v2Pro/test0_e4_s60.pth v2 v2Pro False
# loading sovits_v2Pro <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://fcf13f528aaa43cfdb.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Actual Input Reference Text: 我们小组一致认为九三大阅兵对我们最大的启示。
# Actual Input Target Text: 那我问你，你是男是女，牛魔的
# ...
